# %%
from src.clients import get_race_shutuba_html
from src.parse import parse_shutuba

html = get_race_shutuba_html("202509020611")
parse_shutuba(html)
# Out:
# RaceShutuba(race_name='桜花賞(G1) 出馬表', race_id='', date='2025年4月13日', time='', place='', course='', weather='', condition='', shutuba=[RaceShutubaItem(waku=1, num=1, horse=HorseProfilePicked(horse_name='ヴーレヴー', horse_id='2022104617'), sex_age='牝3', weight='55.0', jockey=JockeyInfoPicked(jockey_name='浜中', jockey_id=''), stable='武幸', stable_id='', odds=0.0, pop=0), RaceShutubaItem(waku=1, num=2, horse=HorseProfilePicked(horse_name='エリカエクスプレス', horse_id='2022103205'), sex_age='牝3', weight='55.0', jockey=JockeyInfoPicked(jockey_name='戸崎圭', jockey_id=''), stable='杉山晴', stable_id='', odds=0.0, pop=0), RaceShutubaItem(waku=2, num=3, horse=HorseProfilePicked(horse_name='マピュース', horse_id='2022105467'), sex_age='牝3', weight='55.0', jockey=JockeyInfoPicked(jockey_name='田辺', jockey_id=''), stable='和田勇', stable_id='', odds=0.0, pop=0), RaceShutubaItem(waku=2, num=4, horse=HorseProfilePicked(horse_name='ショウナンザナドゥ', horse_id='2022105071'), sex_age='牝3', weight='55.0', jockey=JockeyInfoPicked(jockey_n
# ...

# %%
import httpx

race_id = "202509020611"
with httpx.Client() as client:
    response = client.get(
        "https://race.netkeiba.com/race/shutuba.html",
        params={
            "race_id": race_id,
        },
    )
    if response.status_code != httpx.codes.OK:
        raise Exception(f"Failed to fetch data: {response.status_code}")

# %%
response.encoding
response.content
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n<meta charset="EUC-JP">\n\n<!-- block=common__meta_tag_each_race (cg) -->\n<meta http-equiv="content-language" content="ja">\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<meta name="viewport" content="width=1000">\n<meta name="format-detection" content="telephone=no" />\n<meta name="description" content="2025\xc7\xaf4\xb7\xee13\xc6\xfc \xba\xe5\xbf\xc011R \xba\xf9\xb2\xd6\xbe\xde(G1)\xa4\xce\xbd\xd0\xc7\xcf\xc9\xbd\xa4\xc7\xa4\xb9\xa1\xa3JRA" />\n<meta name="keywords" conten
# ...
